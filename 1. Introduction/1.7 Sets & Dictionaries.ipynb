# %% [markdown]
# # Sets and Dictionaries

# %% [markdown]
# ## 1 Sets :
#
# In Python, a set is a built-in data type that stores an unordered collection of unique and immutable elements. While the set itself is mutable (you can add or remove items), the individual items inside it must be of a hashable type, such as strings, integers, or tuples.

# %%
# Sets example 
my_set = {1, 2, 3, 4, 5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
# Operations/Functions of Sets
# 1. Add an element to a set
my_set.add(6)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# 2 . Remove an element from a set
my_set.remove(6)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 3. Check if an element is in a set
print(3 in my_set)  # Output: True
print(6 in my_set)  # Output: False
# Out:
# True
# False

# %%
# 4. Length of a set
print(len(my_set))  # Output: 5
# Out:
# 5

# %%
# Union of set
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}

print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
# Intersection of set
print(set1.intersection(set2))
# Out:
# {4, 5}

# %%
# Deep and shallow copy of set
# Shallow copy
set1 = {1, 2, 3, 4, 5}
set2 = set1.copy()
print(set2)


# Note: do not use variable name 'set', because it shadows Python's built-in set() constructor
# Out:
# {1, 2, 3, 4, 5}

# %%
# Difference
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}
print(set2-set1)
print(set2.difference(set1))
# Out:
# {8, 6, 7}
# {8, 6, 7}

# %%
# symmetric difference
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}
print(set1^set2)
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 6, 7, 8}
# {1, 2, 3, 6, 7, 8}

# %%
# DSA Problems on SETS

# Q1. Given two lists, write a Python program to find the common elements between them using sets.
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]

common_elements = set(list1) & set(list2)
print(common_elements)
# Out:
# {4, 5}

# %%
# Q2. Write a Python program to remove duplicates from a list using sets.
my_list = [1, 2, 3, 4, 5, 1, 2, 3]
unique_elements = list(set(my_list))
print(unique_elements)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Q3. Write a Python program to find the difference between two lists using sets.
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]

difference = set(list1) - set(list2)
print(difference)
# Out:
# {1, 2, 3}

# %% [markdown]
# # Dictionary
#
# Python dictionary is a built-in data structure that stores data collections in key-value pairs. It behaves like a real-world dictionary where you look up a specific word (the key) to find its definition (the value).

# %%
# Example of dictionary 

my_dict = {"name": "John", "age": 30, "city": "New York"}
print(my_dict)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %%
# Methods of Dictionary

# Adding elements in dictionary
my_dict["country"] = "USA"
print(my_dict)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York', 'country': 'USA'}
