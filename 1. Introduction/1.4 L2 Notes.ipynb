# %% [markdown]
# # Time and Space Complexity

# %%
#O(n)
n=2

for i in range(n//2):
  print(i)
  
for i in range(n+100):
  print(i,end="")
  
for i in range(n*100):
  print(i,end="")
# Out:
# 0
# ...
