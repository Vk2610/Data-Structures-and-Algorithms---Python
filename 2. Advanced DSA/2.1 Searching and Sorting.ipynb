# %% [markdown]
# # Sorting Algorithm
#
# Q. What is a sorting algorithm?
#
# -- A sorting algorithm is a method or procedure used to arrange elements in a list or array in a specific order, typically in ascending or descending order. Sorting algorithms are fundamental in computer science and are used in various applications, such as searching, data organization, and optimization. There are many different sorting algorithms, each with its own advantages and disadvantages in terms of efficiency, complexity, and use cases.

# %% [markdown]
# Sorting in a data structure is the process of rearranging a collection of data elements into a specific logical order, most commonly in ascending or descending numerical value, or alphabetical sequence

# %%
class Solution:
    def sortArray(self, nums):
        self.mergeSort(nums, 0, len(nums) - 1)
        return nums

    def mergeSort(self, arr, left, right):
        if left >= right:
            return
        
        mid = (left + right) // 2
        
        self.mergeSort(arr, left, mid)
        self.mergeSort(arr, mid + 1, right)
        
        self.merge(arr, left, mid, right)

    def merge(self, arr, left, mid, right):
        temp = []
        i, j = left, mid + 1
        
        while i <= mid and j <= right:
            if arr[i] <= arr[j]:
                temp.append(arr[i])
                i += 1
            else:
                temp.append(arr[j])
                j += 1
        
        while i <= mid:
            temp.append(arr[i])
            i += 1
        
        while j <= right:
            temp.append(arr[j])
            j += 1
        
        # Copy back to original array
        for k in range(len(temp)):
            arr[left + k] = temp[k]

# %% [markdown]
# # 1. Bubble Sort
# - Bubble Sort is a simple comparison-based sorting algorithm. It works by repeatedly stepping through the list to be sorted, comparing adjacent elements and swapping them if they are in the wrong order. The pass through the list is repeated until the list is sorted.

# %%
# Bubble sort 
class Solution:
    def sortArray(self, nums):
        n = len(nums)
        for i in range(n):
            for j in range(n - i - 1): 
              if nums[j] > nums[j + 1]:
                # Swap the elements
                temp = nums[j]
                nums[j] = nums[j + 1]
                nums[j + 1] = temp
                
        return nums
      
# Array 
arr = [5, 2, 9, 1, 5, 6]
solution = Solution()
sorted_arr = solution.sortArray(arr)
print(sorted_arr)
# Out:
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# # 2. Insertion Sort
# - Insertion sort is a simple, comparison-based sorting algorithm that builds a final sorted array one element at a time. It works by virtually splitting an array into a sorted portion and an unsorted portion. Elements from the unsorted part are picked and placed into their correct position within the sorted part.

# %%
# Example

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        
        # Move elements of arr[0..i-1], that are greater than key,
        # to one position ahead of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

arr = [5, 2, 9, 1, 5, 6]
insertion_sort(arr)
print(arr)
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
# Example 2 : Insertion Sort
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        
        # Move elements of arr[0..i-1], that are greater than key,
        # to one position ahead of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

arr = [5, 2, 9, 1, 5, 6, 3, 8, 7, 4]
insertion_sort(arr)
print(arr)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9]

# %%
# Insertion Sort

class Solution:
    def sortArray(self, nums):
        n = len(nums)

        for i in range(1, n):
            key = nums[i]
            j = i - 1

            while j >= 0 and nums[j] > key:
                nums[j + 1] = nums[j]
                j -= 1

            nums[j + 1] = key

        return nums

# %% [markdown]
# # 3 . Selection Sort
# - Selection Sort is a simple, comparison-based sorting algorithm that works by repeatedly finding the minimum element from the unsorted portion of a list and swapping it into its correct position.
# - The algorithm conceptually splits the array into two regions: a sorted region on the left and an unsorted region on the right. Initially, the sorted section is completely empty, and the unsorted section contains all the original items.

# %%
# Selection Sort Algorithm

class Solution:
    def selection_sort(self, nums):
        n = len(nums)

        for i in range(n):
            min_idx = i

            for j in range(i + 1, n):
                if nums[j] < nums[min_idx]:
                    min_idx = j

            nums[i], nums[min_idx] = nums[min_idx], nums[i]

        return nums

# %%
# Example usage
arr = [5, 2, 9, 1, 5, 6]
solution = Solution()
sorted_arr = solution.selection_sort(arr)
print(sorted_arr)
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

def print_secret_message(doc_url):
    response = requests.get(doc_url)
    text = response.text

    lines = text.splitlines()
    data = []
    
    for line in lines:
        parts = line.strip().split()
        if len(parts) >= 3:
            try:
                char = parts[0]
                x = int(parts[1])
                y = int(parts[2])
                data.append((char, x, y))
            except:
                continue

    if not data:
        print("No valid data found.")
        return

    max_x = max(x for _, x, _ in data)
    max_y = max(y for _, _, y in data)

    grid = [[' ' for _ in range(max_x + 1)] for _ in range(max_y + 1)]

    for char, x, y in data:
        grid[y][x] = char

    for row in grid:
        print(''.join(row))

print_secret_message("https://docs.google.com/document/d/e/2PACX-1vSvM5gDlNvt7npYHhp_XfsJvuntUhq184By5xO_pA4b_gCWeXb6dM6ZxwN8rE6S4ghUsCj2VKR21oEP/pub")
# Out:
#
#  flex:
